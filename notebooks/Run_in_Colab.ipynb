# %% [markdown]
# # AtlasForecast — forecasting + inventory (one-click run)
#
# Ranks forecasting models per SKU, then produces order-up-to recommendations with expected cost.
#
# Press **Runtime -> Run all** (or run each cell top to bottom).

# %%
# !git clone https://github.com/akshay-birla-03/atlas-forecast.git
# %cd atlas-forecast

# %%
# !pip install -q -e .

# %% [markdown]
# ### Run the demo

# %%
# !atlasforecast backtest --skus 4

# %%
# !atlasforecast plan --skus 4
